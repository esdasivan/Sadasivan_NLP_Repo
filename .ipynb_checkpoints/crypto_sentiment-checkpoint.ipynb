# %% [markdown]
# # Unit 12 - Tales from the Crypto
#
# ---

# %% [markdown]
# ## 1. Sentiment Analysis
#
# Use the [newsapi](https://newsapi.org/) to pull the latest news articles for Bitcoin and Ethereum and create a DataFrame of sentiment scores for each coin.
#
# Use descriptive statistics to answer the following questions:
# 1. Which coin had the highest mean positive score?
# 2. Which coin had the highest negative score?
# 3. Which coin had the highest positive score?

# %%
# Initial imports
import os
import pandas as pd
from dotenv import load_dotenv
import nltk as nltk
nltk.download('vader_lexicon')
from nltk.sentiment.vader import SentimentIntensityAnalyzer
analyzer = SentimentIntensityAnalyzer()

# %matplotlib inline
# Out:
# [nltk_data] Downloading package vader_lexicon to C:\Users\sadasivan
# [nltk_data]     evan\AppData\Roaming\nltk_data...
# [nltk_data]   Package vader_lexicon is already up-to-date!

# %%
from newsapi import NewsApiClient

# %%
# Read your api key environment variable
from newsapi import NewsApiClient
# api_key = os.getenv("news_api")
api_key = news_api="9dc49c4da01347a5969879c70aba7a0b"

# %%
# Create a newsapi client
# newsapi = NewsApiClient(api_key=api_key)
newsapi = NewsApiClient(api_key=api_key)

# %%
# Fetch the Bitcoin news articles
bitcoin_news = newsapi.get_everything(
    q="bitcoin",
    language="en"
)
bitcoin_news["totalResults"]
# Out:
# 10174

# %%
# Fetch the Ethereum news articles
eth_news = newsapi.get_everything(
    q="ethereum",
    language="en"
)
eth_news["totalResults"]
# Out:
# 4379

# %%
def create_df(crypto):
    articles = []
    for article in crypto:
        try:
            title = article["title"]
            description = article["description"]
            text = article["content"]
            date = article["publishedAt"][:10]

            articles.append({
                "title": title,
                "description": description,
                "text": text,
                "date": date,
                "language": "en"
            })
        except AttributeError:
            pass

    return pd.DataFrame(articles)
# Create the Bitcoin sentiment scores DataFrame
bitcoin_df = create_df(bitcoin_news["articles"])
bitcoin_df
# Out:
#                                                 title  \
# 0      New York passes a bill to limit bitcoin mining
# 1   Jay-Z and Jack Dorsey Launch Bitcoin Academy f...
# 2   Bitcoin Wasn't as Decentralized or Anonymous a...
# 3    Why the Central African Republic adopted Bitcoin
# 4   El Salvador: The country where you can buy any...
# ..                                                ...
# 95                    Bitcoin Critiques and Rebuttals
# 96  Elon Musk Sued For Billions Over Running Alleg...
# 97  Meta's Novi Service to Be Phased Out: What you...
# 98  Cybercriminals Steal $100 Million in Cryptocur...
# 99  Cryptoverse: The funds making moolah from mess...
#
#                                           description  \
# 0   New York lawmakers have passed a bill\r\n that...
# 1   Rapper and entrepreneur Shawn Carter, better k...
# 2   A new study on bitcoin calls into question whe...
# 3   Some 90% of people in the Central African Repu...
# ...

# %%
def get_sentiment(score):
    """
    Calculates the sentiment based on the compound score.
    """
    result = 0  # Neutral by default
    if score >= 0.05:  # Positive
        result = 1
    elif score <= -0.05:  # Negative
        result = -1

    return result

# %%
title_sent = {
    "title_compound": [],
    "title_pos": [],
    "title_neu": [],
    "title_neg": [],
    "title_sent": [],
}
text_sent = {
    "text_compound": [],
    "text_pos": [],
    "text_neu": [],
    "text_neg": [],
    "text_sent": [],
}

# %%
for index, row in bitcoin_df.iterrows():
    try:
        # Sentiment scoring with VADER
        title_sentiment = analyzer.polarity_scores(row["title"])
        title_sent["title_compound"].append(title_sentiment["compound"])
        title_sent["title_pos"].append(title_sentiment["pos"])
        title_sent["title_neu"].append(title_sentiment["neu"])
        title_sent["title_neg"].append(title_sentiment["neg"])
        title_sent["title_sent"].append(get_sentiment(title_sentiment["compound"]))

        text_sentiment = analyzer.polarity_scores(row["text"])
        text_sent["text_compound"].append(text_sentiment["compound"])
        text_sent["text_pos"].append(text_sentiment["pos"])
        text_sent["text_neu"].append(text_sentiment["neu"])
        text_sent["text_neg"].append(text_sentiment["neg"])
        text_sent["text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# %%
title_sentiment_df = pd.DataFrame(title_sent)
text_sentiment_df = pd.DataFrame(text_sent)
bitcoin_sent_df = bitcoin_df.join(title_sentiment_df).join(text_sentiment_df)

# %%
title_sentiment_df
# Out:
#     title_compound  title_pos  title_neu  title_neg  title_sent
# 0           0.0000      0.000      1.000      0.000           0
# 1           0.0000      0.000      1.000      0.000           0
# 2           0.0000      0.000      1.000      0.000           0
# 3           0.0000      0.000      1.000      0.000           0
# 4           0.0000      0.000      1.000      0.000           0
# ..             ...        ...        ...        ...         ...
# 95          0.0000      0.000      1.000      0.000           0
# 96          0.3612      0.143      0.857      0.000           1
# 97          0.0000      0.000      1.000      0.000           0
# 98         -0.4939      0.000      0.652      0.348          -1
# 99         -0.3612      0.000      0.762      0.238          -1
#
# [100 rows x 5 columns]

# %%
bitcoin_sent_df.head(10)
# Out:
#                                                title  \
# 0     New York passes a bill to limit bitcoin mining
# 1  Jay-Z and Jack Dorsey Launch Bitcoin Academy f...
# 2  Bitcoin Wasn't as Decentralized or Anonymous a...
# 3   Why the Central African Republic adopted Bitcoin
# 4  El Salvador: The country where you can buy any...
# 5  El Salvador's Bitcoin investment suffers amid ...
# 6           Recommended Reading: A blockchain primer
# 7  Three Arrows Capital Ordered to Liquidate All ...
# 8       DeFi lending giant Celsius halts withdrawals
# 9  Grayscale is suing the SEC after its spot bitc...
#
#                                          description  \
# 0  New York lawmakers have passed a bill\r\n that...
# 1  Rapper and entrepreneur Shawn Carter, better k...
# 2  A new study on bitcoin calls into question whe...
# 3  Some 90% of people in the Central African Repu...
# 4  The cryptocurrency crash is hurting many inves...
# 5  El Salvador has embraced Bitcoin like no other...
# ...

# %%
bitcoin_sent_df.describe()
# Out:
#        title_compound   title_pos   title_neu  title_neg  title_sent  \
# count      100.000000  100.000000  100.000000  100.00000  100.000000
# mean        -0.059145    0.055530    0.851250    0.09321   -0.110000
# std          0.297872    0.103112    0.170837    0.13856    0.709175
# min         -0.908100    0.000000    0.361000    0.00000   -1.000000
# 25%         -0.255800    0.000000    0.744000    0.00000   -1.000000
# 50%          0.000000    0.000000    0.889000    0.00000    0.000000
# 75%          0.000000    0.101000    1.000000    0.16025    0.000000
# max          0.771700    0.492000    1.000000    0.63900    1.000000
#
#        text_compound    text_pos    text_neu    text_neg   text_sent
# count     100.000000  100.000000  100.000000  100.000000  100.000000
# mean       -0.013109    0.063550    0.870300    0.066210    0.010000
# std         0.431023    0.066257    0.084031    0.070238    0.893241
# min        -0.948500    0.000000    0.628000    0.000000   -1.000000
# ...

# %%
bitcoin_averages=bitcoin_sent_df.drop(['title','description','text'], axis=1)

# %%
bitcoin_averages
# Out:
#           date language  title_compound  title_pos  title_neu  title_neg  \
# 0   2022-06-03       en          0.0000      0.000      1.000      0.000
# 1   2022-06-09       en          0.0000      0.000      1.000      0.000
# 2   2022-06-08       en          0.0000      0.000      1.000      0.000
# 3   2022-06-05       en          0.0000      0.000      1.000      0.000
# 4   2022-06-16       en          0.0000      0.000      1.000      0.000
# ..         ...      ...             ...        ...        ...        ...
# 95  2022-06-30       en          0.0000      0.000      1.000      0.000
# 96  2022-06-16       en          0.3612      0.143      0.857      0.000
# 97  2022-07-02       en          0.0000      0.000      1.000      0.000
# 98  2022-06-24       en         -0.4939      0.000      0.652      0.348
# 99  2022-06-14       en         -0.3612      0.000      0.762      0.238
#
#     title_sent  text_compound  text_pos  text_neu  text_neg  text_sent
# ...

# %%
av_column = bitcoin_averages.mean(axis=0)
print (av_column)
# Out:
# title_compound   -0.059145
# title_pos         0.055530
# title_neu         0.851250
# title_neg         0.093210
# title_sent       -0.110000
# text_compound    -0.013109
# text_pos          0.063550
# text_neu          0.870300
# text_neg          0.066210
# text_sent         0.010000
# dtype: float64
# C:\Users\sadasivan evan\AppData\Local\Temp\ipykernel_35892\1643085195.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   av_column = bitcoin_averages.mean(axis=0)

# %%
eth_df = create_df(eth_news["articles"])
eth_df
# Out:
#                                                 title  \
# 0   ‘Axie Infinity’ hack victims will only get bac...
# 1   Guy Who Told Everyone to Buy Ethereum at $2,90...
# 2   Ethereum Mining No Longer Profitable For Many ...
# 3   PayPal Lets Users Transfer Bitcoin and Ethereu...
# 4   MoonDAO Will Pick 2 of the Next Blue Origin As...
# ..                                                ...
# 95  Seth Green's Stolen NFT Ape 'Is Home,' Safe an...
# 96  Crypto 101: What Exactly Is Proof of Stake and...
# 97  Why Bitcoin, Ethereum, Solana, and Dogecoin Dr...
# 98  Why Coinbase, Ethereum, and Solana Are Down on...
# 99  Why Bitcoin, Ethereum, and Dogecoin Dropped Do...
#
#                                           description  \
# 0   Sky Mavis, the developer of blockchain game Ax...
# 1   Jim Cramer, the CNBC host who’s reportedly wor...
# 2   For the first time since 2020, Ethereum mining...
# 3   PayPal announced on Tuesday that the service n...
# ...

# %%
eth_title_sent = {
    "eth_title_compound": [],
    "eth_title_pos": [],
    "eth_title_neu": [],
    "eth_title_neg": [],
    "eth_title_sent": [],
}
eth_text_sent = {
    "eth_text_compound": [],
    "eth_text_pos": [],
    "eth_text_neu": [],
    "eth_text_neg": [],
    "eth_text_sent": [],
}

# %%
# Create the Ethereum sentiment scores DataFrame
for index, row in eth_df.iterrows():
    try:
        # Sentiment scoring with VADER
        eth_title_sentiment = analyzer.polarity_scores(row["title"])
        eth_title_sent["eth_title_compound"].append(title_sentiment["compound"])
        eth_title_sent["eth_title_pos"].append(title_sentiment["pos"])
        eth_title_sent["eth_title_neu"].append(title_sentiment["neu"])
        eth_title_sent["eth_title_neg"].append(title_sentiment["neg"])
        eth_title_sent["eth_title_sent"].append(get_sentiment(title_sentiment["compound"]))

        eth_text_sentiment = analyzer.polarity_scores(row["text"])
        eth_text_sent["eth_text_compound"].append(text_sentiment["compound"])
        eth_text_sent["eth_text_pos"].append(text_sentiment["pos"])
        eth_text_sent["eth_text_neu"].append(text_sentiment["neu"])
        eth_text_sent["eth_text_neg"].append(text_sentiment["neg"])
        eth_text_sent["eth_text_sent"].append(get_sentiment(text_sentiment["compound"]))
    except AttributeError:
        pass

# %%
eth_title_sentiment_df = pd.DataFrame(eth_title_sent)
eth_text_sentiment_df = pd.DataFrame(eth_text_sent)
eth_sent_df = eth_df.join(eth_title_sentiment_df).join(eth_text_sentiment_df)

# %%
eth_sent_df.head(10)
# Out:
#                                                title  \
# 0  ‘Axie Infinity’ hack victims will only get bac...
# 1  Guy Who Told Everyone to Buy Ethereum at $2,90...
# 2  Ethereum Mining No Longer Profitable For Many ...
# 3  PayPal Lets Users Transfer Bitcoin and Ethereu...
# 4  MoonDAO Will Pick 2 of the Next Blue Origin As...
# 5      It’s Time To Get Interested In Ethereum Again
# 6     New York passes a bill to limit bitcoin mining
# 7  eBay now has an established NFT marketplace at...
# 8  Crypto panic as digital assets follow share pr...
# 9  Crypto Platform Coinbase Cuts More Than 1,000 ...
#
#                                          description  \
# 0  Sky Mavis, the developer of blockchain game Ax...
# 1  Jim Cramer, the CNBC host who’s reportedly wor...
# 2  For the first time since 2020, Ethereum mining...
# 3  PayPal announced on Tuesday that the service n...
# 4  A community of cryptocurrency enthusiasts crow...
# 5  The Winklevoss twins are cutting the staff at ...
# ...

# %%
eth_averages=eth_sent_df.drop(['title','description','text'], axis=1)

# %%
eth_averages.describe()
# Out:
#        eth_title_compound  eth_title_pos  eth_title_neu  eth_title_neg  \
# count        1.000000e+02          100.0   1.000000e+02   1.000000e+02
# mean        -3.612000e-01            0.0   7.620000e-01   2.380000e-01
# std          2.789540e-16            0.0   3.347448e-16   3.626402e-16
# min         -3.612000e-01            0.0   7.620000e-01   2.380000e-01
# 25%         -3.612000e-01            0.0   7.620000e-01   2.380000e-01
# 50%         -3.612000e-01            0.0   7.620000e-01   2.380000e-01
# 75%         -3.612000e-01            0.0   7.620000e-01   2.380000e-01
# max         -3.612000e-01            0.0   7.620000e-01   2.380000e-01
#
#        eth_title_sent  eth_text_compound  eth_text_pos  eth_text_neu  \
# count           100.0       1.000000e+02         100.0  1.000000e+02
# mean             -1.0      -6.486000e-01           0.0  8.450000e-01
# std               0.0       4.463264e-16           0.0  7.810713e-16
# ...

# %%
av_column = eth_averages.mean(axis=0)
print (av_column)
# Out:
# eth_title_compound   -0.3612
# eth_title_pos         0.0000
# eth_title_neu         0.7620
# eth_title_neg         0.2380
# eth_title_sent       -1.0000
# eth_text_compound    -0.6486
# eth_text_pos          0.0000
# eth_text_neu          0.8450
# eth_text_neg          0.1550
# eth_text_sent        -1.0000
# dtype: float64
# C:\Users\sadasivan evan\AppData\Local\Temp\ipykernel_35892\2453101199.py:1: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   av_column = eth_averages.mean(axis=0)

# %%
bitcoin_df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 100 entries, 0 to 99
# Data columns (total 5 columns):
#  #   Column       Non-Null Count  Dtype
# ---  ------       --------------  -----
#  0   title        100 non-null    object
#  1   description  100 non-null    object
#  2   text         100 non-null    object
#  3   date         100 non-null    object
#  4   language     100 non-null    object
# dtypes: object(5)
# memory usage: 4.0+ KB

# %%
# Describe the Bitcoin Sentiment
# Bitcoin got a lot of attention, by and large the commentary on it is neutral, but the negative sentiments in the titles outweigh the positive. The negative sentiments in the text also outweigh the positives, but this one is much closer.

# %%
# Describe the Ethereum Sentiment
# Ethereum also had mostly neutral coverage in the articles. Nearly none of the article titles were positive, while about a third were negative.Within the text of the articles nearly all was neutral with a small amount of positive sentiment and almost no negative.

# %% [markdown]
# ### Questions:
#
# Q: Which coin had the highest mean positive score?
#
# A: within the text of the artcles, bitcoin had the higher score, with a mean of 0.064320.
#
# Q: Which coin had the highest compound score?
#
# A: Ethereum had the higher compound score with 0.4019. (Bitcoin's mean compound score for the text of the articles was negative).
#
# Q. Which coin had the highest positive score?
#
# A: Bitcoin had the highest count of articles with positive text, with a count of 100.

# %% [markdown]
# ---

# %% [markdown]
# ## 2. Natural Language Processing
# ---
# ###   Tokenizer
#
# In this section, you will use NLTK and Python to tokenize the text for each coin. Be sure to:
# 1. Lowercase each word.
# 2. Remove Punctuation.
# 3. Remove Stopwords.

# %%
from nltk.tokenize import word_tokenize, sent_tokenize
from nltk.corpus import stopwords
from nltk.stem import WordNetLemmatizer, PorterStemmer
from string import punctuation
import re

# %%
# Instantiate the lemmatizer
lemmatizer = WordNetLemmatizer()

# Create a list of stopwords
sw = set(stopwords.words('english'))

# Expand the default stopwords list if necessary
# YOUR CODE HERE!

# %%
# Complete the tokenizer function
def tokenizer(text):
    """Tokenizes text."""
    
    tokenized_words =[]
    
    # Remove the punctuation from text
    regex = re.compile("[^a-zA-Z ]")
    re_clean = regex.sub('', text)
    
    # Create a tokenized list of the words
    words = word_tokenize(re_clean)
    
    # Lemmatize words into root words
    lem = [lemmatizer.lemmatize(word) for word in words]
   
    # Convert the words to lowercase 
    output = [word.lower() for word in words if word.lower() not in sw]
    
    
    # Remove the stop words
    
    #append to list
    tokenized_words=tokenized_words+output
    
    return ' '.join(output)

# %%
nltk.download('wordnet')
nltk.download('omw-1.4')
# Out:
# [nltk_data] Downloading package wordnet to C:\Users\sadasivan
# [nltk_data]     evan\AppData\Roaming\nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!
# [nltk_data] Downloading package omw-1.4 to C:\Users\sadasivan
# [nltk_data]     evan\AppData\Roaming\nltk_data...
# [nltk_data]   Package omw-1.4 is already up-to-date!
# True

# %%
# Create a new tokens column for Bitcoin
bitcoin_tokenized = [tokenizer(text) for text in bitcoin_sent_df['text']]

# %%
bitcoin_sent_df["words"]=bitcoin_tokenized

# %%
# Create a new tokens column for Ethereum
eth_tokenized = [tokenizer(text) for text in eth_sent_df['text']]

# %%
eth_sent_df["words"]=eth_tokenized

# %% [markdown]
# ---

# %% [markdown]
# ### NGrams and Frequency Analysis
#
# In this section you will look at the ngrams and word frequency for each coin.
#
# 1. Use NLTK to produce the n-grams for N = 2.
# 2. List the top 10 words for each coin.

# %%
from collections import Counter
from nltk import ngrams

# %%
# Generate the bitcoin N-grams where N=2
bitcoin_bigrams = ngrams(bitcoin_sent_df['words'], 2)

# %%
# Generate the Ethereum N-grams where N=2
eth_bigrams = ngrams(eth_sent_df['words'], 2)

# %%
# Function token_count generates the top 10 words for a given coin
def token_count(tokens, N=3):
    """Returns the top N tokens from the frequency count"""
    return Counter(tokens).most_common(N)

# %%
# Use token_count to get the top 10 words for Bitcoin
top_words_list=[]
for row in bitcoin_sent_df['words']:
    top_words=token_count(row,10)
    top_words_list.append(top_words)

# %%
most_common=Counter(" ".join(bitcoin_sent_df["text"]).split()).most_common(10)
most_common
# Out:
# [('the', 139),
#  ('chars]', 96),
#  ('to', 79),
#  ('a', 78),
#  ('of', 76),
#  ('and', 54),
#  ('in', 53),
#  ('on', 49),
#  ('The', 41),
#  ('as', 36)]

# %%
# Use token_count to get the top 10 words for Ethereum
most_common=Counter(" ".join(eth_sent_df["text"]).split()).most_common(10)
most_common
# Out:
# [('the', 133),
#  ('chars]', 95),
#  ('and', 81),
#  ('of', 70),
#  ('a', 70),
#  ('to', 68),
#  ('in', 60),
#  ('The', 49),
#  ('is', 37),
#  ('on', 36)]

# %% [markdown]
# ---

# %% [markdown]
# ### Word Clouds
#
# In this section, you will generate word clouds for each coin to summarize the news for each coin

# %%
from wordcloud import WordCloud
import matplotlib.pyplot as plt
plt.style.use('seaborn-whitegrid')
import matplotlib as mpl
mpl.rcParams['figure.figsize'] = [20.0, 10.0]

# %%
# Generate the Bitcoin word cloud
bitcoin_big_string = ' '.join(bitcoin_sent_df['words'])
wc = WordCloud().generate(bitcoin_big_string)
plt.imshow(wc)

# %%
# Generate the Ethereum word cloud
eth_big_string = ' '.join(eth_sent_df['words'])
wc = WordCloud().generate(eth_big_string)
plt.imshow(wc)

# %% [markdown]
# ---
# ## 3. Named Entity Recognition
#
# In this section, you will build a named entity recognition model for both Bitcoin and Ethereum, then visualize the tags using SpaCy.

# %%
import spacy
from spacy import displacy

# %%
# Download the language model for SpaCy
 #!python -m spacy download en_core_web_sm

# %%
# Load the spaCy model
nlp = spacy.load('en_core_web_sm')

# %% [markdown]
# ---
# ### Bitcoin NER

# %%
# Concatenate all of the Bitcoin text together
bitcoin_concat=bitcoin_big_string

# %%
# Run the NER processor on all of the text
bitcoin_doc = nlp(bitcoin_concat)

# Add a title to the document
bitcoin_doc.user_data["title"] = "Bitcoin NER"

# %%
# Render the visualization
displacy.render(bitcoin_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Bitcoin NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #feca74; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     new york
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">GPE</span>
# </mark>
#  lawmakers passed bill would temporarily ban new bitcoin mining operations
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     early friday
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">DATE</span>
# </mark>
#  state senators voted pass legislation bound desk chars rapper entrepreneur shawn carter better known
# ...

# %%
# List all Entities
bitcoin_entities = [ent.text for ent in bitcoin_doc.ents]
print(bitcoin_entities)
# Out:
# ['new york', 'early friday', 'jayz', 'thursday', 'jayz', 'ceo jack dorsey', 'joe', 'hundreds', 'last year', 'three', 'one', 'tuesday', 'paris', 'one', 'sec', 'june', 'gmt monday', 'years', 'june', 'monday', 'june', 'reuters', 'tuesday', 'microstrategy inc mstro', 'june', 'thursday', 'june', 'saturday', 'june', 'saturday', 'june', 'first', 'monday', 'billions', 'june', 'reuters', 'wednesday new month', 'june', 'sunday', 'kellogg', 'june', 'tuesday', 'june', 'wednesday', 'one', 'wednesday', 'june', 'thursday', 'years', 'san salvador', 'june', 'el salvadors', 'monday', 'american', 'robert cyran', 'june', 'jacobi asset management', 'thursday', 'first', 'elon musk', 'november', 'monday', 'saturday', 'sunday', 'june', 'winter', 'el salvador', 'token holdings plungethe central', 'american', 'june', 'winter', 'washington', 'june', 'thursday', 'south african', 'joe biden', 'june', 'reuters', 'wednesday', 'hong kong', 'june', 'reuters', 'tuesday', 'new month', 'one', 'weeks', 'june', 'el salva
# ...

# %% [markdown]
# ---

# %% [markdown]
# ### Ethereum NER

# %%
# Concatenate all of the Ethereum text together
eth_concat=eth_big_string

# %%
# Run the NER processor on all of the text
eth_doc = nlp(eth_concat)

# Add a title to the document
eth_doc.user_data["title"] = "Ethereum NER"

# %%
# Render the visualization
displacy.render(eth_doc, style='ent')
# Out:
# <span class="tex2jax_ignore"><h2 style="margin: 0">Ethereum NER</h2>
#
# <div class="entities" style="line-height: 2.5; direction: ltr">
# <mark class="entity" style="background: #aa9cfc; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     sky mavis
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">PERSON</span>
# </mark>
#  developer blockchain game axie infinity says start reimbursing victims
# <mark class="entity" style="background: #e4e7d2; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
#     million
#     <span style="font-size: 0.8em; font-weight: bold; line-height: 1; border-radius: 0.35em; vertical-align: middle; margin-left: 0.5rem">CARDINAL</span>
# </mark>
#  hack took place
# <mark class="entity" style="background: #bfe1d9; padding: 0.45em 0.6em; margin: 0 0.25em; line-height: 1; border-radius: 0.35em;">
# ...

# %%
# List all Entities
eth_entities = [ent.text for ent in eth_doc.ents]
print(eth_entities)
# Out:
# ['sky mavis', 'million', 'earlier year', 'million', 'worth least million', 'brooklyn', 'new england connecticut maine', 'massachusetts', 'today', 'two', 'first', 'new york', 'early friday', 'ebay', 'ebay', 'today', 'one', 'three', 'one', 'tuesday', 'june', 'thursday', 'june', 'saturday', 'june', 'gmt monday', 'years', 'june', 'monday', 'yudkowsky', 'elon musk', 'june', 'sunday elon musk', 'hours musk', 'hundreds', 'first', 'several years ago', 'kim kardashian', 'nba', 'gallon', 'june', 'thursday', 'years chars june', 'hong', 'friday', 'three', 'monday', 'billions', 'june', 'friday', 'june', 'sunday', 'million', 'millions', 'recent years', 'years', 'algorand smart', 'massachusett', 'recent years', 'july', 'july', 'two', 'ceo brian', 'recent years', 'million', 'crypto lender blockfi digital asset companies', 'cameron tyler', 'today', 'xsullo', 'london', 'first', 'late saturday', 'last two years', 'kitco news markets across board reeling wild price', 'dan frommera', 'recent weeks', 'kit
# ...

# %% [markdown]
# ---
